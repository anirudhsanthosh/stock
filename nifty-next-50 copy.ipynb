# %%
import yfinance as yf
import pandas as pd 
import datetime
from dateutil.relativedelta import relativedelta

# %%
index = pd.read_csv("nifty-next-50.csv", index_col=False)

# %%
index.head()
# Out:
#        SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0  NIFTY NEXT 50  40,511.05  40,653.25  40,160.35      41,225.65  40,354.25
# 1           PGHH  13,482.00  13,819.95  13,191.85      13,482.90  13,819.95
# 2         ZOMATO      59.30      62.30      57.65          61.15      61.70
# 3     ADANITRANS   2,700.00   2,871.25   2,690.15       2,801.65   2,822.20
# 4         COLPAL   1,560.00   1,594.00   1,553.00       1,571.10   1,582.50
#
#    CHNG \n  %CHNG \n  VOLUME \n(shares)             VALUE    52W H \n  \
# 0  -871.40     -2.11          273330713  81,203,379,080.14  45,290.80
# 1   337.05      2.50               4635      62,440,726.95  16,448.70
# 2     0.55      0.90           47189321   2,774,260,181.59     169.00
# 3    20.55      0.73             345791     965,911,831.94   3,000.00
# 4    11.40      0.73             414530     655,044,451.30   1,823.40
#
#     52W L \n 365 D % CHNG \n 28-Apr-2021  30 D % CHNG \n 29-Mar-2022
# 0  35,627.45                       12.67                       -5.68
# 1  12,310.10                        1.93                       -4.81
# 2      57.65                           -                      -26.67
# 3     863.00                      139.42                       14.98
# 4   1,375.60                        4.62                       -0.37

# %%
nifty_next_50 = index["SYMBOL \n"][1:]

# %%
returns = {}

for symbol in nifty_next_50:

    ticker = symbol+".NS"

    print(symbol)

    price = yf.download(ticker, start="2021-05-04", end="2022-11-04")

    price.drop(["Adj Close", "Volume"], axis=1, inplace=True)

    month_open = price.iloc[0]["Open"]
    month_close = price.iloc[-1]["Close"]


    returns[symbol] = [(month_close / month_open) - 1, month_open, month_close]
# Out:
# PGHH
# [*********************100%***********************]  1 of 1 completed
# ZOMATO
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS
# [*********************100%***********************]  1 of 1 completed
# COLPAL
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN
# [*********************100%***********************]  1 of 1 completed
# IOC
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N
# [*********************100%***********************]  1 of 1 completed
# LUPIN
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM
# [*********************100%***********************]  1 of 1 completed
# ADANIENT
# [*********************100%***********************]  1 of 1 completed
# BANKBARODA
# [*********************100%***********************]  1 of 1 completed
# GAIL
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK
# [*********************100%***********************]  1 of 1 completed
# GODREJCP
# [*********************100%***********************]  1 of 1 completed
# ZYDUSLIFE
# [*********************100%***********************]  1 of 1 completed
# ICICIGI
# [*********************100%***********************]  1 of 1 completed
# HAVELLS
# [*********************100%***********************]  1 of 1 completed
# PNB
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER
# [*********************100%***********************]  1 of 1 completed
# PAYTM
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG
# [*********************100%***********************]  1 of 1 completed
# INDIGO
# [*********************100%***********************]  1 of 1 completed
# ACC
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM
# [*********************100%***********************]  1 of 1 completed
# PEL
# [*********************100%***********************]  1 of 1 completed
# BOSCHLTD
# [*********************100%***********************]  1 of 1 completed
# DLF
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT
# [*********************100%***********************]  1 of 1 completed
# NMDC
# [*********************100%***********************]  1 of 1 completed
# JUBLFOOD
# [*********************100%***********************]  1 of 1 completed
# MARICO
# [*********************100%***********************]  1 of 1 completed
# DABUR
# [*********************100%***********************]  1 of 1 completed
# VEDL
# [*********************100%***********************]  1 of 1 completed
# SIEMENS
# [*********************100%***********************]  1 of 1 completed
# GLAND
# [*********************100%***********************]  1 of 1 completed
# MINDTREE
# [*********************100%***********************]  1 of 1 completed
# SRF
# [*********************100%***********************]  1 of 1 completed
# NYKAA
# [*********************100%***********************]  1 of 1 completed
# LTI
# [*********************100%***********************]  1 of 1 completed
# BIOCON
# [*********************100%***********************]  1 of 1 completed
# SAIL
# [*********************100%***********************]  1 of 1 completed
# SBICARD
# [*********************100%***********************]  1 of 1 completed
# PIIND
# [*********************100%***********************]  1 of 1 completed
# NAUKRI
# [*********************100%***********************]  1 of 1 completed
# DMART
# [*********************100%***********************]  1 of 1 completed
# CHOLAFIN
# [*********************100%***********************]  1 of 1 completed

# %%
returns = {k: v for k, v in sorted(returns.items(), key=lambda item: item[1][0])}

# %%
for k, v in returns.items():

    print(k, v[0] * 100,",      open :",v[1],",        Close :", v[2])
    print(' ')
# Out:
# PAYTM -67.02307754907852 ,      open : 1950.0 ,        Close : 643.0499877929688
#
# PEL -47.66939109730943 ,      open : 1712.0 ,        Close : 895.9000244140625
#
# ZOMATO -46.379309687121165 ,      open : 116.0 ,        Close : 62.20000076293945
#
# NYKAA -44.09811815728754 ,      open : 2018.0 ,        Close : 1128.0999755859375
#
# SAIL -37.31688129167712 ,      open : 129.6999969482422 ,        Close : 81.30000305175781
#
# LUPIN -33.92865050380266 ,      open : 1077.8499755859375 ,        Close : 712.1500244140625
#
# GLAND -33.26039871298598 ,      open : 2765.0 ,        Close : 1845.3499755859375
#
# NMDC -31.133253878687118 ,      open : 160.60000610351562 ,        Close : 110.5999984741211
#
# INDUSTOWER -28.375288211858564 ,      open : 262.20001220703125 ,        Close : 187.8000030517578
#
# BANDHANBNK -27.437890094259508 ,      open : 322.0 ,        Close : 233.64999389648438
#
# BIOCON -26.574803149606296 ,      open : 381.0 ,        Close : 279.75
#
# ZYDUSLIFE -25.272573441825486 ,      open : 587.0 ,        Close : 438.6499938964844
#
# HDFCAMC -23.840292153470966 ,      open : 2755.0 ,        Close : 2098.199951171875
#
# NAUKRI -19.199547883271684 ,      open : 4866.0 ,        Close : 3931.75
#
# ICICIGI -18.970796163291027 ,      open : 1438.0 ,        Close : 1165.199951171875
#
# SBICARD -16.416328184066277 ,      open : 992.0 ,        Close : 829.1500244140625
#
# BERGEPAINT -14.789324128225944 ,      open : 712.0 ,        Close : 606.7000122070312
#
# MUTHOOTFIN -9.15529420369845 ,      open : 1164.9000244140625 ,        Close : 1058.25
#
# ICICIPRULI -6.459455060529285 ,      open : 555.0 ,        Close : 519.1500244140625
#
# GAIL -1.9314073381828223 ,      open : 92.33333587646484 ,        Close : 90.55000305175781
#
# DABUR 2.0000044796445016 ,      open : 545.0 ,        Close : 555.9000244140625
#
# PGHH 2.847998065868862 ,      open : 13604.2998046875 ,        Close : 13991.75
#
# JUBLFOOD 5.005177559204843 ,      open : 579.4000244140625 ,        Close : 608.4000244140625
#
# COLPAL 6.010672153831731 ,      open : 1499.0 ,        Close : 1589.0999755859375
#
# INDIGO 7.014833897440642 ,      open : 1685.0 ,        Close : 1803.199951171875
#
# IOC 11.405405050964568 ,      open : 61.666664123535156 ,        Close : 68.69999694824219
#
# GODREJCP 16.999573981664206 ,      open : 710.9000244140625 ,        Close : 831.75
#
# VEDL 18.32031011581421 ,      open : 256.0 ,        Close : 302.8999938964844
#
# PNB 18.678161329031795 ,      open : 34.79999923706055 ,        Close : 41.29999923706055
#
# MARICO 19.128040709506067 ,      open : 453.0 ,        Close : 539.6500244140625
#
# HAVELLS 19.278653714025438 ,      open : 1012.0 ,        Close : 1207.0999755859375
#
# BOSCHLTD 21.847820962727216 ,      open : 13589.0 ,        Close : 16557.900390625
#
# LTI 22.786094899771637 ,      open : 3941.0 ,        Close : 4839.0
#
# ACC 28.417892136833167 ,      open : 1912.0 ,        Close : 2455.35009765625
#
# PIIND 28.93749576877216 ,      open : 2517.14990234375 ,        Close : 3245.550048828125
#
# TORNTPHARM 33.234767081156406 ,      open : 1268.0999755859375 ,        Close : 1689.550048828125
#
# CHOLAFIN 34.95819401080151 ,      open : 562.0999755859375 ,        Close : 758.5999755859375
#
# DMART 44.22971785806396 ,      open : 2908.0 ,        Close : 4194.2001953125
#
# PIDILITIND 45.650140431301644 ,      open : 1815.0 ,        Close : 2643.550048828125
#
# SIEMENS 52.83034084715248 ,      open : 1892.0 ,        Close : 2891.550048828125
#
# DLF 53.59281437125749 ,      open : 250.5 ,        Close : 384.75
#
# MINDTREE 64.28084777136903 ,      open : 2129.25 ,        Close : 3497.949951171875
#
# MCDOWELL-N 70.14285714285715 ,      open : 525.0 ,        Close : 893.25
#
# AMBUJACEM 71.26984126984127 ,      open : 315.0 ,        Close : 539.5
#
# SRF 94.37595872574201 ,      open : 1314.0 ,        Close : 2554.10009765625
#
# BAJAJHLDNG 96.0587550901687 ,      open : 3438.0 ,        Close : 6740.5
#
# ADANIGREEN 100.63809058779762 ,      open : 1050.0 ,        Close : 2106.699951171875
#
# BANKBARODA 120.46131045302029 ,      open : 67.19999694824219 ,        Close : 148.14999389648438
#
# ADANIENT 179.4085527115759 ,      open : 1285.0 ,        Close : 3590.39990234375
#
# ADANITRANS 202.03210113245413 ,      open : 1090.0 ,        Close : 3292.14990234375
